# %% [markdown]
# <a href="https://colab.research.google.com/github/aryanksh/colab-test/blob/main/colab_gh_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # github test

# %%
x = 1
y = 2

# %%
x+y
# Out:
# 3

# %%
# !git clone https://github.com/aryanksh/colab-test
# Out:
# Cloning into 'colab-test'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.

# %%
x = 5
y = 100
x+y
# Out:
# 105

# %%
# !git
# Out:
# fatal: not a git repository (or any of the parent directories): .git
